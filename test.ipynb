# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'items': '50', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': 'COMSOL Releases Version 6.3 of COMSOL Multiphysics®', 'url': 'https://www.benzinga.com/pressreleases/24/11/g42071577/comsol-releases-version-6-3-of-comsol-multiphysics', 'time_published': '20241119T184745', 'authors': ['Globe Newswire'], 'summary': 'BURLINGTON, Mass., Nov. 19, 2024 ( GLOBE NEWSWIRE ) -- COMSOL, a global leader in modeling and simulation software, today announced the release of COMSOL Multiphysics® version 6.3, which delivers new features and capability updates for efficient physics modeling and simulation app development.', 'banner_image': 'https://ml.globenewswire.com/Resource/Download/a849f0c5-5d31-4fdb-967f-3c218ac5610e/acoustics-gpu-pressure-time-comsol.png', 'source': 'Benzinga', 'category_within_source': 'General', 'source_domain': 'www.benzinga.com', 'topics': [{'topic': 'Real Estate & Construction', 'relevance_score': '0.333333'}, {'topic': 'Technology', 'relevance_score': '0.333333'}, {'topic': 'Manufacturing', 'relevance_score': '0.333333'}], 'overall_sentiment_score': 0.242471, 'overall_sentiment_label': 'Somewhat-Bullish', 'ticker_sentiment': [{'ticker': 'APG', 'relevance_score': '0.043264', 'ticker_sentiment_score': '0.017831', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'MSFT', 'relevance_score': '0.0864', 'ticker_sentiment_score': '0.0', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'AAPL', 'relevance_score': '0.043264', 'ticker_sentiment_score': '0.0', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'CAE', 'relevance_score': '0.043264', 'ticker_sentiment_score': '0.098895', 'ticker_sentiment_label': 'Neutral'}]}, {'title': "Apple's $100 Million Gamble, Tech Giant Moves to Lift Indonesia's iPhone Ban - Alphabet  ( NASDAQ:GOOG ) , Apple  ( NASDAQ:AAPL ) ", 'url': 'https://www.benzinga.com/24/11/42071334/apples-100-million-gamble-tech-giant-moves-to-lift-indonesias-iphone-ban', 'time_published': '20241119T183307', 'authors': ['Anusuya Lahiri'], 'summary': "Apple Inc AAPL is stepping up its efforts to address a sales ban on its iPhone 16 in Indonesia by proposing a substantial $100 million investment. The tech giant aims to strengthen its position in one of Southeast Asia's largest markets by meeting the country's stringent domestic content ...", 'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/11/19/iPhone.png?width=1200&height=800&fit=crop', 'source': 'Benzinga', 'category_within_source': 'News', 'source_domain': 'www.benzinga.com', 'topics': [{'topic': 'Technology', 'relevance_score': '1.0'}, {'topic': 'Financial Markets', 'relevance_score': '0.365926'}], 'overall_sentiment_score': 0.01205, 'overall_sentiment_label': 'Neutral', 'ticker_sentiment': [{'ticker': 'GOOG', 'relevance_score': '0.227716', 'ticker_sentiment_score': '0.077932', 'ticker_sentiment_label': 'Neutral'}, {'ticker': 'AAPL', 'relevance_score': '0.614697', 'ticker_sentiment_score': '-0.152219', 'ticker_sentiment_label': 'Somewhat-Bearish'}, {'ticker': 'FOREX:IDR', 'relevance_score': '0.076847', 'ticker_sentiment_score': '0.0', 'ticker_sentiment_label': 'Neutral'}]}, {'title': 'S&P 500 To Reach 6,500 By End Of 2025, Analysts Predict: Could It Spark M&A Revival? - Apple  ( NASDAQ:AAPL ) , Amazon.com  ( NASDAQ:AMZN ) ', 'url': 'https://www.benzinga.com/economics/macro-economic-events/24/11/42069891/sp-500-to-reach-6500-by-end-of-2025-analysts-predict-could-it-spark-ma-revival', 'time_published': '20241119T173725', 'authors': ['Piero Cingari'], 'summary': "Wall Street analysts are painting optimistic pictures for the U.S. stock market heading into 2025, with the S&P 500 index - as tracked by the SPDR S&P 500 ETF Trust SPY - expected to climb to 6,500 points by year's end, according to both Goldman Sachs and Mor ...
